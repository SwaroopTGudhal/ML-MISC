# %% [markdown]
# ### packages in environment at
# ### c:\users\user\anaconda3\envs\tensorflow02.xxxx:
#
# ### Name                     Version                           Build  Channel
# absl-py                   0.12.0                   pypi_0    pypi
# argon2-cffi               20.1.0                   pypi_0    pypi
# astunparse                1.6.3                    pypi_0    pypi
# async-generator           1.10                     pypi_0    pypi
# attrs                     20.3.0                   pypi_0    pypi
# backcall                  0.2.0                    pypi_0    pypi
# bleach                    3.3.0                    pypi_0    pypi
# cachetools                4.2.1                    pypi_0    pypi
# certifi                   2020.12.5        py36haa95532_0
# cffi                      1.14.5                   pypi_0    pypi
# chardet                   4.0.0                    pypi_0    pypi
# colorama                  0.4.4                    pypi_0    pypi
# decorator                 4.4.2                    pypi_0    pypi
# defusedxml                0.7.1                    pypi_0    pypi
# entrypoints               0.3                      pypi_0    pypi
# gast                      0.3.3                    pypi_0    pypi
# google-auth               1.28.0                   pypi_0    pypi
# google-auth-oauthlib      0.4.3                    pypi_0    pypi
# google-pasta              0.2.0                    pypi_0    pypi
# grpcio                    1.36.1                   pypi_0    pypi
# h5py                      2.10.0                   pypi_0    pypi
# idna                      2.10                     pypi_0    pypi
# importlib-metadata        3.7.3                    pypi_0    pypi
# ipykernel                 5.5.0                    pypi_0    pypi
# ipython                   7.16.1                   pypi_0    pypi
# ipython-genutils          0.2.0                    pypi_0    pypi
# ipywidgets                7.6.3                    pypi_0    pypi
# jedi                      0.18.0                   pypi_0    pypi
# jinja2                    2.11.3                   pypi_0    pypi
# joblib                    1.0.1                    pypi_0    pypi
# jsonschema                3.2.0                    pypi_0    pypi
# jupyter                   1.0.0                    pypi_0    pypi
# jupyter-client            6.1.12                   pypi_0    pypi
# jupyter-console           6.4.0                    pypi_0    pypi
# jupyter-core              4.7.1                    pypi_0    pypi
# jupyterlab-pygments       0.1.2                    pypi_0    pypi
# jupyterlab-widgets        1.0.0                    pypi_0    pypi
# keras-preprocessing       1.1.2                    pypi_0    pypi
# markdown                  3.3.4                    pypi_0    pypi
# markupsafe                1.1.1                    pypi_0    pypi
# matplotlib                3.3.4                    pypi_0    pypi
# mistune                   0.8.4                    pypi_0    pypi
# nbclient                  0.5.3                    pypi_0    pypi
# nbconvert                 6.0.7                    pypi_0    pypi
#
# Note: you may need to restart the kernel to use updated packages.nbformat                  5.1.2                    pypi_0    pypi
# nest-asyncio              1.5.1                    pypi_0    pypi
# notebook                  6.3.0                    pypi_0    pypi
# oauthlib                  3.1.0                    pypi_0    pypi
# opencv-python             4.5.1.48                 pypi_0    pypi
# opt-einsum                3.3.0                    pypi_0    pypi
# packaging                 20.9                     pypi_0    pypi
# pandas                    1.1.5                    pypi_0    pypi
# pandocfilters             1.4.3                    pypi_0    pypi
# parso                     0.8.1                    pypi_0    pypi
# pickleshare               0.7.5                    pypi_0    pypi
# pip                       21.0.1           py36haa95532_0
# prometheus-client         0.9.0                    pypi_0    pypi
# prompt-toolkit            3.0.18                   pypi_0    pypi
# protobuf                  3.15.6                   pypi_0    pypi
# pyasn1                    0.4.8                    pypi_0    pypi
# pyasn1-modules            0.2.8                    pypi_0    pypi
# pycparser                 2.20                     pypi_0    pypi
# pygments                  2.8.1                    pypi_0    pypi
# pyrsistent                0.17.3                   pypi_0    pypi
# python                    3.6.9                h5500b2f_0
# pytz                      2021.1                   pypi_0    pypi
# pywin32                   300                      pypi_0    pypi
# pywinpty                  0.5.7                    pypi_0    pypi
# pyzmq                     22.0.3                   pypi_0    pypi
# qtconsole                 5.0.3                    pypi_0    pypi
# qtpy                      1.9.0                    pypi_0    pypi
# requests                  2.25.1                   pypi_0    pypi
# requests-oauthlib         1.3.0                    pypi_0    pypi
# rsa                       4.7.2                    pypi_0    pypi
# scikit-learn              0.24.1                   pypi_0    pypi
# scipy                     1.4.1                    pypi_0    pypi
# seaborn                   0.11.1                   pypi_0    pypi
# send2trash                1.5.0                    pypi_0    pypi
# setuptools                52.0.0           py36haa95532_0
# sklearn                   0.0                      pypi_0    pypi
# sqlite                    3.35.2               h2bbff1b_0
# tensorboard               2.2.2                    pypi_0    pypi
# tensorboard-plugin-wit    1.8.0                    pypi_0    pypi
# tensorflow                2.2.0                    pypi_0    pypi
# tensorflow-estimator      2.2.0                    pypi_0    pypi
#
# termcolor                 1.1.0                    pypi_0    pypi
# terminado                 0.9.3                    pypi_0    pypi
# testpath                  0.4.4                    pypi_0    pypi
# threadpoolctl             2.1.0                    pypi_0    pypi
# tornado                   6.1                      pypi_0    pypi
# traitlets                 4.3.3                    pypi_0    pypi
# typing-extensions         3.7.4.3                  pypi_0    pypi
# urllib3                   1.26.4                   pypi_0    pypi
# vc                        14.2                 h21ff451_1
# vs2015_runtime            14.27.29016          h5e58377_2
# wcwidth                   0.2.5                    pypi_0    pypi
# webencodings              0.5.1                    pypi_0    pypi
# werkzeug                  1.0.1                    pypi_0    pypi
# wheel                     0.36.2             pyhd3eb1b0_0
# widgetsnbextension        3.5.1                    pypi_0    pypi
# wincertstore              0.2              py36h7fe50ca_0
# wrapt                     1.12.1                   pypi_0    pypi
# zipp                      3.4.1                    pypi_0    pypi

# %%
# with frame rate equal to video frame rate



import cv2
import time
import os

def video_to_frames(input_loc, output_loc):
    """Function to extract frames from input video file
    and save them as separate frames in an output directory.
    Args:
        input_loc: Input video file.
        output_loc: Output directory to save the frames.
    Returns:
        None
    """
    try:
        os.mkdir(output_loc)
    except OSError:
        pass
    # Log the time
    time_start = time.time()
    # Start capturing the feed
    cap = cv2.VideoCapture(input_loc)
    # Find the number of frames
    video_length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT)) - 1
    print ("Number of frames: ", video_length)
    count = 0
    print ("Converting video..\n")
    # Start converting the video
    while cap.isOpened():
        # Extract the frame
        ret, frame = cap.read()
        # Write the results back to output location.
        cv2.imwrite(output_loc + "/%#05d.jpg" % (count+1), frame)
        count = count + 1
        # If there are no more frames left
        if (count > (video_length-1)):
            # Log the time again
            time_end = time.time()
            # Release the feed
            cap.release()
            # Print stats
            print ("Done extracting frames.\n%d frames extracted" % count)
            print ("It took %d seconds forconversion." % (time_end-time_start))
            break

            
# uncomment below to run the code            
#if __name__=="__main__":

    input_loc = (r"C:\Users\User\Downloads\MyVideo8.mp4")
    output_loc = (r"C:\Users\User\Desktop\Allok\dummy")
    video_to_frames(input_loc, output_loc)

# %%
# with changeable frame rate

import cv2

vidcap = cv2.VideoCapture(r"C:\Users\User\Downloads\MyVideo8.mp4")
def getFrame(sec): 
    vidcap.set(cv2.CAP_PROP_POS_MSEC,sec*1000) 
    hasFrames,image = vidcap.read() 
    if hasFrames: 
        cv2.imwrite(r"C:/Users/User/Desktop/Allok/dummy/onepersec/"+"/%#05d.jpg" % (sec+1), image)     # save frame as JPG file 
        #cv2.imwrite(output_loc + "/%#05d.jpg" % (count+1), frame)
    return hasFrames
sec = 0 
frameRate = 1   # it will capture image in each second 
success = getFrame(sec)
success
while success: 
    sec = sec + frameRate 
    sec = round(sec, 2) 
    success = getFrame(sec)

# %%
# convert frames to video

import cv2
import os

image_folder = (r"C:\Users\User\Desktop\Allok\dummy\onepersec")
video_name = (r"C:\Users\User\Desktop\Allok\dummy\newvideo01.mp4")

images = [img for img in os.listdir(image_folder) if img.endswith(".jpg")]
frame = cv2.imread(os.path.join(image_folder, images[2]))
height, width, layers = frame.shape

video = cv2.VideoWriter(video_name,0,30, (width,height))
# in above line 30 is frame per sec(fps), we can alter it as per need

for image in images:
    video.write(cv2.imread(os.path.join(image_folder, image)))

cv2.destroyAllWindows()
video.release()
